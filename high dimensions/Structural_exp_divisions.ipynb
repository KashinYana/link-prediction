# %%
import graphviz as gv
import pydot
import random
import numpy    
from sklearn.metrics import roc_auc_score
from  sklearn.ensemble import RandomForestClassifier as RF
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import NMF
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import coo_matrix
from time import gmtime, strftime
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import math

# %%
def add_nodes(graph, nodes):
    for n in nodes:
        if isinstance(n, tuple):
            graph.node(n[0], **n[1])
        else:
            graph.node(n)
    return graph

def add_edges(graph, edges):
    for e in edges:
        if isinstance(e[0], tuple):
            graph.edge(*e[0], **e[1])
        else:
            graph.edge(*e)
    return graph

# %%
def dist(u, w, nodes_pos, A=[]):
    nodes_pos_u = nodes_pos[u]
    nodes_pos_w = nodes_pos[w]
    length = len(nodes_pos_u)
    dist = 0.0
    for i in range(length):
        dist = dist + (nodes_pos_u[i] - nodes_pos_w[i])**2
        
    return (dist)**0.5

def mf_score(u, w, nodes_pos, A):
    return numpy.dot(A[int(u)], A[int(w)])

# %%
def make_dataset(nodes_pos, pos_set, neg_set, functs, A=[]):
    X = []
    Y = []
    
    for edge in pos_set:
        u, w = edge
        x = []
        for func in functs:
            x.append(func(u, w, nodes_pos, A))
        X.append(x)
        Y.append(1)
        
    for edge in neg_set:
        u, w = edge
        x = []
        for func in functs:
            x.append(func(u, w, nodes_pos, A))
        X.append(x)
        Y.append(0)
        
    X = numpy.array(X)
    Y = numpy.array(Y)
    return X, Y

# %%
def make_sparse_matrix(train_set, n):
    row = []
    col = []
    data = []
    for edge in train_set:
        u = int(edge[0])
        w = int(edge[1])
        row.append(u)
        col.append(w)
        row.append(w)
        col.append(u)
        data.append(1)
        data.append(1)
    return coo_matrix((data, (row, col)), shape=(n, n))

# %%
def read_train(dataset_name):
    max_id = 0
    file_name = dataset_name + "/train.in"
    fin_train = open(file_name, 'r')
    edges = set()
    nodes = set()
    for line in fin_train:
        line = line.strip()
        u, w = line.split()
        max_id = max(max_id, int(u))
        max_id = max(max_id, int(w))
        edges.add((u,w))
        nodes.add(u)
        nodes.add(w)
    fin_train.close()
    
    return edges, nodes, max_id

# %%
def get_sets(nodes, edges, division=10):
    nodes_size = len(nodes)
    edges_size = len(edges)
    print "Nodes size: " + str(nodes_size)
    print "Edges size: " + str(edges_size)
    test_size = int(edges_size * (division / 100.0))
    pos_edges = random.sample(edges, test_size)
    pos_edges = set(pos_edges)

    neg_edges = set()
    while len(neg_edges) < test_size:
        u = random.sample(nodes, 1)[0]
        w = random.sample(nodes, 1)[0]
        edge = (str(u),str(w))
        if edge not in edges and u != w:
            neg_edges.add(edge)
        
    edges_not_full = edges - pos_edges
    
    return pos_edges, neg_edges, edges_not_full

# %%
def render_graph(dataset_name, dimension, nodes, edges_not_full):
    graph = gv.Graph(format="dot")
    graph.engine = 'sfdp'
    graph.graph_attr['dim'] = str(dimension)
    graph.graph_attr['dimen'] = str(dimension)
    graph = add_nodes(graph, nodes)
    graph = add_edges(graph, edges_not_full)
    file_name = dataset_name + "/graph" + str(dimension)
    graph.render(file_name, view=False)
    
    graph.format = "png"
    graph.render(file_name, view=False)
    
    return

# %%
def read_edges_dot(dataset_name, dimension):
    file_name = dataset_name + "/graph" + str(dimension) + ".dot"
    dot_graph = pydot.graph_from_dot_file(file_name)[0]
    dot_nodes = dot_graph.get_nodes()
    nodes_pos = {}
    for node in dot_nodes:
        name = node.get_name()
        if name != 'node' and name != 'graph':
            pos_str = node.get('pos').strip('"')        
            nodes_pos[name] = map(float, pos_str.split(','))
    return nodes_pos

# %%
def auc_sfdp(nodes_pos, pos_edges, neg_edges):
    X, Y = make_dataset(nodes_pos, pos_edges, neg_edges, [dist])
    clf = RF()
    scores = cross_val_score(clf, X, Y, cv=10, scoring='roc_auc')
    print("ROC AUC SFDP: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    return scores

# %%
def auc_nmf(edges, nodes_pos, pos_edges, neg_edges, n_components, max_id):
    G = make_sparse_matrix(edges, max_id + 1)
    model = NMF(n_components=n_components, init='random')
    A = model.fit_transform(G)

    X, Y = make_dataset(nodes_pos, pos_edges, neg_edges, [mf_score], A)
    clf = RF()
    scores = cross_val_score(clf, X, Y, cv=10, scoring='roc_auc')
    print("ROC AUC NMF: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    return scores

# %%
def auc_svd(edges, nodes_pos, pos_edges, neg_edges, n_components, max_id):
    G = make_sparse_matrix(edges, max_id + 1)
    model = TruncatedSVD(n_components=n_components, algorithm='arpack')
    A = model.fit_transform(G)

    X, Y = make_dataset(nodes_pos, pos_edges, neg_edges, [mf_score], A)
    clf = RF()
    scores = cross_val_score(clf, X, Y, cv=10, scoring='roc_auc')
    print("ROC AUC SVD: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    return scores

# %%
def compute_mean(dim, nodes_pos):
    values = []

    for i in range(dim):
        values.append([])

    for node in nodes_pos:
        for i in range(dim):
            values[i].append(nodes_pos[node][i])
        
    for i in range(dim):
        print np.mean(values[i])
        print np.std(values[i])
        print

# %%
def draw_graph(dataset_name, nodes_pos, edges):
    xs = []
    ys = []
    zs = []

    for node in nodes_pos:
        xs.append(nodes_pos[node][0])
        ys.append(nodes_pos[node][1])
        zs.append(nodes_pos[node][2])
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(xs, ys, zs, s=2.0, c='b', marker='o')

    for edge in edges:
        u = edge[0]
        w = edge[1]
        ax.plot([nodes_pos[u][0], nodes_pos[w][0]], [nodes_pos[u][1], nodes_pos[w][1]],zs=[nodes_pos[u][2], nodes_pos[w][2]], linewidth=1.0)

    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')

    file_name = dataset_name + "/3d.png"
    #plt.show()
    fig.savefig(file_name)

# %%
def run_exp(dataset_name, dimension, n_components, division):
    print "Read train"
    edges, nodes, max_id = read_train(dataset_name)
    
    print "Get sets"
    pos_edges, neg_edges, edges_not_full = get_sets(nodes, edges, division)
    
    print "Render graph"
    print strftime("%Y-%m-%d %H:%M:%S", gmtime())
    render_graph(dataset_name, dimension, nodes, edges_not_full)
    
    print "Read edges"
    print strftime("%Y-%m-%d %H:%M:%S", gmtime())
    nodes_pos = read_edges_dot(dataset_name, dimension)
    
    print "Compute mean and std"
    compute_mean(dimension, nodes_pos)
    
    if dimension == 3:
        print "Draw graph"
        draw_graph(dataset_name, nodes_pos, edges)
    
    print "SFDP"
    print strftime("%Y-%m-%d %H:%M:%S", gmtime())
    auc_sfdp(nodes_pos, pos_edges, neg_edges)
    
    print "NMF"
    print strftime("%Y-%m-%d %H:%M:%S", gmtime())
    auc_nmf(edges, nodes_pos, pos_edges, neg_edges, n_components, max_id)
    
    print "SVD"
    print strftime("%Y-%m-%d %H:%M:%S", gmtime())
    auc_svd(edges, nodes_pos, pos_edges, neg_edges, n_components, max_id)
    
    return

# %%
def run_dim_exp(dataset_name, num_exps, dimensions):
    dim_scores_sfdp = {}
    dim_scores_nmf = {}
    dim_scores_svd = {}
    for dimension in dimensions:
            dim_scores_sfdp[dimension] = np.array([])
            dim_scores_nmf[dimension] = np.array([])
            dim_scores_svd[dimension] = np.array([])
            
    edges, nodes, max_id = read_train(dataset_name)
    
    for i in range(num_exps):
        print "Launch " + str(i)
        print strftime("%Y-%m-%d %H:%M:%S", gmtime())
            
        pos_edges, neg_edges, edges_not_full = get_sets(nodes, edges)
    
        for dimension in dimensions:
            print "Dimension " + str(dimension)
            render_graph(dataset_name, dimension, nodes, edges_not_full)
            nodes_pos = read_edges_dot(dataset_name, dimension)
            
            if dimension == 3:
                print "Draw graph"
                draw_graph(dataset_name, nodes_pos, edges)
            
            print "SFDP"
            sfdp_scores = auc_sfdp(nodes_pos, pos_edges, neg_edges)
            dim_scores_sfdp[dimension] = np.append(dim_scores_sfdp[dimension], sfdp_scores)
    
            print "NMF"
            nmf_scores = auc_nmf(edges, nodes_pos, pos_edges, neg_edges, dimension, max_id)
            dim_scores_nmf[dimension] = np.append(dim_scores_nmf[dimension], nmf_scores)
    
            print "SVD"
            svd_scores = auc_svd(edges, nodes_pos, pos_edges, neg_edges, dimension, max_id)
            dim_scores_svd[dimension] = np.append(dim_scores_svd[dimension], svd_scores)
    
    return dim_scores_sfdp, dim_scores_nmf, dim_scores_svd

# %%
def save_scores(dataset_name, dimensions, dim_scores_sfdp, dim_scores_nmf, dim_scores_svd):
    scores_sfdp = []
    scores_nmf = []
    scores_svd = []
    
    for dim in dimensions:
        scores_sfdp.append(dim_scores_sfdp[dim].mean())
        scores_nmf.append(dim_scores_nmf[dim].mean())
        scores_svd.append(dim_scores_svd[dim].mean())
    
    print "SFDP scores"
    print scores_sfdp        
    print
    print "NMF scores"
    print scores_nmf        
    print
    print "SVD scores"
    print scores_svd        
    print
    
    fig, ax = plt.subplots( nrows=1, ncols=1 )
    ax.plot(dimensions, scores_sfdp, label='sfdp', linewidth=3)
    ax.plot(dimensions, scores_nmf, label='nmf', linewidth=3)
    ax.plot(dimensions, scores_svd, label='svd', linewidth=3)
    ax.legend()
    
    for dim in dimensions:
        size = len(dim_scores_sfdp[dim])
        ax.plot([dim] * size, dim_scores_sfdp[dim], c='r', marker='o', markersize=3, linewidth=0)
        ax.plot([dim] * size, dim_scores_nmf[dim], c='r', marker='o', markersize=3, linewidth=0)
        ax.plot([dim] * size, dim_scores_svd[dim], c='r', marker='o', markersize=3, linewidth=0)
    
    file_name = dataset_name + "/dimensions.png"
    fig.savefig(file_name)

# %%
fig, ax = plt.subplots( nrows=1, ncols=1 )
ax.plot([2, 2], [1,2], linewidth=3)
ax.plot([2.2, 2, 2.1], [1, 1, 1], c='r', marker='o', markersize=5, linewidth=0)
file_name = "dimensions.png"
fig.savefig(file_name)

# %%
#dataset_names = ["airport", "Ca-HelpTh", "chicago", "Conflict", "euroroad", "EuroSiS", "PowerGrid"]
#dimensions = [2, 3, 4, 5, 6, 7, 8 ,9, 10]

dataset_names = ["airport", "Ca-HelpTh", "chicago", "Conflict", "euroroad", "EuroSiS", "PowerGrid"]
dimensions = [2, 3]

for dataset_name in dataset_names:
    print dataset_name
    dim_scores_sfdp, dim_scores_nmf, dim_scores_svd = run_dim_exp(dataset_name, 1, dimensions)
    print "saving"
    save_scores(dataset_name, dimensions, dim_scores_sfdp, dim_scores_nmf, dim_scores_svd)
# Out:
# airport
# Launch 0
# 2017-05-01 16:26:56
# Nodes size: 1574
# Edges size: 28236
# Dimension 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9944724952f2> in <module>()
#       7 for dataset_name in dataset_names:
#       8     print dataset_name
# ----> 9     dim_scores_sfdp, dim_scores_nmf, dim_scores_svd = run_dim_exp(dataset_name, 1, dimensions)
#      10     print "saving"
#      11     save_scores(dataset_name, dimensions, dim_scores_sfdp, dim_scores_nmf, dim_scores_svd)
#
# <ipython-input-16-3bc0ded38f3f> in run_dim_exp(dataset_name, num_exps, dimensions)
#      18         for dimension in dimensions:
#      19             print "Dimension " + str(dimension)
# ---> 20             render_graph(dataset_name, dimension, nodes, edges_not_full)
#      21             nodes_pos = read_edges_dot(dataset_name, dimension)
#      22
#
# <ipython-input-8-5cd0ee490c33> in render_graph(dataset_name, dimension, nodes, edges_not_full)
#      10
#      11     graph.format = "png"
# ---> 12     graph.render(file_name, view=False)
#      13
#      14     return
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/graphviz/files.pyc in render(self, filename, directory, view, cleanup)
#     144         filepath = self.save(filename, directory)
#     145
# --> 146         rendered = backend.render(self._engine, self._format, filepath)
#     147
#     148         if cleanup:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/graphviz/backend.pyc in render(engine, format, filepath)
#      93
#      94     try:
# ---> 95         subprocess.call(args, startupinfo=STARTUPINFO)
#      96     except OSError as e:
#      97         if e.errno == errno.ENOENT:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in call(*popenargs, **kwargs)
#     520     retcode = call(["ls", "-l"])
#     521     """
# --> 522     return Popen(*popenargs, **kwargs).wait()
#     523
#     524
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in wait(self)
#    1382             while self.returncode is None:
#    1383                 try:
# -> 1384                     pid, sts = _eintr_retry_call(os.waitpid, self.pid, 0)
#    1385                 except OSError as e:
#    1386                     if e.errno != errno.ECHILD:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     474     while True:
#     475         try:
# --> 476             return func(*args)
#     477         except (OSError, IOError) as e:
#     478             if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %%
def run_division_exp(dataset_name, num_exps, divisions, dimension):
    div_scores_sfdp = {}
    div_scores_nmf = {}
    div_scores_svd = {}
    for div in divisions:
            div_scores_sfdp[div] = np.array([])
            div_scores_nmf[div] = np.array([])
            div_scores_svd[div] = np.array([])
            
    edges, nodes, max_id = read_train(dataset_name)
    
    for i in range(num_exps):
        print "Launch " + str(i)
        print strftime("%Y-%m-%d %H:%M:%S", gmtime())
        for div in divisions:
            
            print "Division " + str(div) + "/%"
            pos_edges, neg_edges, edges_not_full = get_sets(nodes, edges, div)
    
            render_graph(dataset_name, dimension, nodes, edges_not_full)
            nodes_pos = read_edges_dot(dataset_name, dimension)
            
            print "SFDP"
            sfdp_scores = auc_sfdp(nodes_pos, pos_edges, neg_edges)
            div_scores_sfdp[div] = np.append(div_scores_sfdp[div], sfdp_scores)
    
            print "NMF"
            nmf_scores = auc_nmf(edges, nodes_pos, pos_edges, neg_edges, 10, max_id)
            div_scores_nmf[div] = np.append(div_scores_nmf[div], nmf_scores)
    
            print "SVD"
            svd_scores = auc_svd(edges, nodes_pos, pos_edges, neg_edges, 30, max_id)
            div_scores_svd[div] = np.append(div_scores_svd[div], svd_scores)
    
    return div_scores_sfdp, div_scores_nmf, div_scores_svd

# %%
def save_scores_div(dataset_name, dimension, divisions, div_scores_sfdp, div_scores_nmf, div_scores_svd):
    scores_sfdp = []
    scores_nmf = []
    scores_svd = []
    
    for div in divisions:
        scores_sfdp.append(div_scores_sfdp[div].mean())
        scores_nmf.append(div_scores_nmf[div].mean())
        scores_svd.append(div_scores_svd[div].mean())
    
    print "SFDP scores"
    print scores_sfdp        
    print
    print "NMF scores"
    print scores_nmf        
    print
    print "SVD scores"
    print scores_svd        
    print
        
    fig, ax = plt.subplots( nrows=1, ncols=1 )
    ax.plot(divisions, scores_sfdp, label='sfdp', linewidth=3)
    ax.plot(divisions, scores_nmf, label='nmf', linewidth=3)
    ax.plot(divisions, scores_svd, label='svd', linewidth=3)
    ax.legend()
    
    for div in divisions:
        size = len(div_scores_sfdp[div])
        ax.plot([div] * size, div_scores_sfdp[div], c='b', marker='o', markersize=3, linewidth=0)
        ax.plot([div] * size, div_scores_nmf[div], c='g', marker='o', markersize=3, linewidth=0)
        ax.plot([div] * size, div_scores_svd[div], c='r', marker='o', markersize=3, linewidth=0)
    
    ax.set_xlabel('Test set size, /%')
    ax.set_ylabel('AUC')  
    
    file_name = dataset_name + "/divisions"  + str(dimension) + ".png"
    fig.savefig(file_name)

# %%
#dataset_names = ["airport", "Ca-HelpTh", "chicago", "Conflict", "euroroad", "EuroSiS", "PowerGrid"]
#dimensions = [2, 3, 4, 10]
dataset_names = ["airport", "Ca-HelpTh", "EuroSiS", "PowerGrid"]
#dataset_names = ["Conflict"]
divisions = [10, 30, 50, 70, 90]
dimensions = [2, 3]
n_components = [30]

for dataset_name in dataset_names:
    for dimension in dimensions:
        for component in n_components:
            print "Dataset: " + dataset_name
            print "Dim: " + str(dimension)
            print "Components: " + str(component)
            print
            div_scores_sfdp, div_scores_nmf, div_scores_svd = run_division_exp(dataset_name, 1, divisions, dimension)
            save_scores_div(dataset_name, dimension, divisions, div_scores_sfdp, div_scores_nmf, div_scores_svd)
            print "---------------------------"
            print
            print
# Out:
# Dataset: airport
# Dim: 2
# Components: 30
#
# Launch 0
# 2017-05-01 16:52:10
# Division 10/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.89 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.90 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.02)
# Division 30/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.90 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.94 (+/- 0.01)
# Division 50/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.91 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.94 (+/- 0.01)
# Division 70/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.91 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.94 (+/- 0.01)
# Division 90/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.89 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.95 (+/- 0.01)
# SFDP scores
# [0.89326947650950594, 0.9047803972350501, 0.91318701450211925, 0.91041529963881751, 0.89396654977899637]
#
# NMF scores
# [0.89506488692626685, 0.91880642701722459, 0.9229115866588995, 0.91985705132789786, 0.91745635449177276]
#
# SVD scores
# [0.92152602798516714, 0.93556137433458475, 0.93895875431871245, 0.94051246164205016, 0.94612477766867753]
#
# ---------------------------
#
#
# Dataset: airport
# Dim: 3
# Components: 30
#
# Launch 0
# 2017-05-01 17:01:18
# Division 10/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.92 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.89 (+/- 0.03)
# SVD
# ROC AUC SVD: 0.93 (+/- 0.02)
# Division 30/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.92 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.90 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.93 (+/- 0.01)
# Division 50/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.93 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.94 (+/- 0.01)
# Division 70/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.92 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.94 (+/- 0.01)
# Division 90/%
# Nodes size: 1574
# Edges size: 28236
# SFDP
# ROC AUC SFDP: 0.91 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.92 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.95 (+/- 0.01)
# SFDP scores
# [0.91810388378043351, 0.92355023424573712, 0.9265047984869913, 0.92444915201486366, 0.91294415298563858]
#
# NMF scores
# [0.88750717704772586, 0.9039771594724908, 0.92169465052745159, 0.91903967262737374, 0.91760140423657255]
#
# SVD scores
# [0.92594119154105459, 0.93371709861459773, 0.93782068258145546, 0.94385595544626977, 0.94666771573176955]
#
# ---------------------------
#
#
# Dataset: Ca-HelpTh
# Dim: 2
# Components: 30
#
# Launch 0
# 2017-05-01 17:10:43
# Division 10/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.93 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.75 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.86 (+/- 0.02)
# Division 30/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.93 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.80 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.88 (+/- 0.01)
# Division 50/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.92 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.79 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.89 (+/- 0.01)
# Division 70/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.89 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.80 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.90 (+/- 0.01)
# Division 90/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.82 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.80 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.91 (+/- 0.00)
# SFDP scores
# [0.93150538746886702, 0.92541831281601161, 0.91570779343821884, 0.89097512979941629, 0.81758660793912752]
#
# NMF scores
# [0.7524932635751258, 0.79543421966060368, 0.7891020839227475, 0.80393621241528501, 0.80456733889601273]
#
# SVD scores
# [0.85957387673454821, 0.88033984383423858, 0.88961711177544112, 0.90385384673103375, 0.91493421170484857]
#
# ---------------------------
#
#
# Dataset: Ca-HelpTh
# Dim: 3
# Components: 30
#
# Launch 0
# 2017-05-01 21:38:27
# Division 10/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.95 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.76 (+/- 0.04)
# SVD
# ROC AUC SVD: 0.86 (+/- 0.02)
# Division 30/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.94 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.78 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.88 (+/- 0.01)
# Division 50/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.94 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.79 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.89 (+/- 0.01)
# Division 70/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.92 (+/- 0.00)
# NMF
# ROC AUC NMF: 0.80 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.90 (+/- 0.01)
# Division 90/%
# Nodes size: 9877
# Edges size: 51971
# SFDP
# ROC AUC SFDP: 0.82 (+/- 0.01)
# NMF
# ROC AUC NMF: 0.80 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.01)
# SFDP scores
# [0.9514440108162846, 0.94471348543780331, 0.9350413890425987, 0.91900773051235196, 0.81780225522046535]
#
# NMF scores
# [0.76337842423925095, 0.78451537969995244, 0.79262082485441376, 0.80375364312933972, 0.80440301048260443]
#
# SVD scores
# [0.85823799607844631, 0.8791043208429512, 0.88868225005565871, 0.90102820128822592, 0.91537499681504619]
#
# ---------------------------
#
#
# Dataset: EuroSiS
# Dim: 2
# Components: 30
#
# Launch 0
# 2017-05-01 22:14:21
# Division 10/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.87 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.90 (+/- 0.04)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.06)
# Division 30/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.84 (+/- 0.04)
# NMF
# ROC AUC NMF: 0.88 (+/- 0.04)
# SVD
# ROC AUC SVD: 0.91 (+/- 0.04)
# Division 50/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.83 (+/- 0.03)
# NMF
# ROC AUC NMF: 0.91 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.02)
# Division 70/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.77 (+/- 0.05)
# NMF
# ROC AUC NMF: 0.90 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.02)
# Division 90/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.61 (+/- 0.03)
# NMF
# ROC AUC NMF: 0.89 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.01)
# SFDP scores
# [0.86970237379807691, 0.83725578676905155, 0.83033796434334484, 0.77481242353165158, 0.60734190075383176]
#
# NMF scores
# [0.89735319780880174, 0.88085172837918935, 0.90519357451363336, 0.89751923539330269, 0.89278434087651992]
#
# SVD scores
# [0.91883555034208586, 0.9149918854535255, 0.92228370354279132, 0.92108215640164559, 0.91961690474619517]
#
# ---------------------------
#
#
# Dataset: EuroSiS
# Dim: 3
# Components: 30
#
# Launch 0
# 2017-05-01 22:17:50
# Division 10/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.87 (+/- 0.06)
# NMF
# ROC AUC NMF: 0.90 (+/- 0.06)
# SVD
# ROC AUC SVD: 0.91 (+/- 0.05)
# Division 30/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.85 (+/- 0.04)
# NMF
# ROC AUC NMF: 0.89 (+/- 0.03)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.03)
# Division 50/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.84 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.88 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.91 (+/- 0.02)
# Division 70/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.80 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.89 (+/- 0.03)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.01)
# Division 90/%
# Nodes size: 1285
# Edges size: 6462
# SFDP
# ROC AUC SFDP: 0.64 (+/- 0.04)
# NMF
# ROC AUC NMF: 0.89 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.92 (+/- 0.01)
# SFDP scores
# [0.8736185078818417, 0.85356550574622914, 0.83501645412104364, 0.80031370570951554, 0.63696992580022582]
#
# NMF scores
# [0.89672904435558431, 0.88652094810152704, 0.88476206530679957, 0.88718858459233885, 0.89251688071212754]
#
# SVD scores
# [0.91112051301312869, 0.9165947718633195, 0.9130264145966267, 0.91946237274855291, 0.91747094728601886]
#
# ---------------------------
#
#
# Dataset: PowerGrid
# Dim: 2
# Components: 30
#
# Launch 0
# 2017-05-01 22:21:32
# Division 10/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.82 (+/- 0.06)
# NMF
# ROC AUC NMF: 0.61 (+/- 0.05)
# SVD
# ROC AUC SVD: 0.84 (+/- 0.04)
# Division 30/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.67 (+/- 0.04)
# NMF
# ROC AUC NMF: 0.58 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.82 (+/- 0.03)
# Division 50/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.55 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.63 (+/- 0.03)
# SVD
# ROC AUC SVD: 0.83 (+/- 0.03)
# Division 70/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.51 (+/- 0.03)
# NMF
# ROC AUC NMF: 0.61 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.82 (+/- 0.03)
# Division 90/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.51 (+/- 0.04)
# NMF
# ROC AUC NMF: 0.60 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.83 (+/- 0.02)
# SFDP scores
# [0.82440502116376246, 0.66595572954908921, 0.55155205977251265, 0.50688609701141285, 0.50942442783402142]
#
# NMF scores
# [0.61270890725436178, 0.58390540348492737, 0.63212624942577678, 0.60714445263721972, 0.59744898381910538]
#
# SVD scores
# [0.83813685537461757, 0.82430204797283024, 0.83242359042119474, 0.82241815042350441, 0.82914114004899298]
#
# ---------------------------
#
#
# Dataset: PowerGrid
# Dim: 3
# Components: 30
#
# Launch 0
# 2017-05-01 22:38:31
# Division 10/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.81 (+/- 0.08)
# NMF
# ROC AUC NMF: 0.59 (+/- 0.04)
# SVD
# ROC AUC SVD: 0.84 (+/- 0.04)
# Division 30/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.67 (+/- 0.07)
# NMF
# ROC AUC NMF: 0.60 (+/- 0.05)
# SVD
# ROC AUC SVD: 0.84 (+/- 0.03)
# Division 50/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.58 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.62 (+/- 0.03)
# SVD
# ROC AUC SVD: 0.83 (+/- 0.03)
# Division 70/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.51 (+/- 0.03)
# NMF
# ROC AUC NMF: 0.63 (+/- 0.02)
# SVD
# ROC AUC SVD: 0.82 (+/- 0.03)
# Division 90/%
# Nodes size: 4941
# Edges size: 6594
# SFDP
# ROC AUC SFDP: 0.52 (+/- 0.02)
# NMF
# ROC AUC NMF: 0.60 (+/- 0.01)
# SVD
# ROC AUC SVD: 0.83 (+/- 0.03)
# SFDP scores
# [0.80524148423449127, 0.66985906071312296, 0.57629198273919391, 0.51494107458328364, 0.51775223978257812]
#
# NMF scores
# [0.59431701631701628, 0.60438169504206396, 0.61932594957877607, 0.63140938220296006, 0.59538256688009361]
#
# SVD scores
# [0.8383071706847931, 0.84399341627049451, 0.83082742329510262, 0.82315524922190764, 0.82913032043340262]
#
# ---------------------------
